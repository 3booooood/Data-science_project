# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/mobile_addiction_cleaned.csv')
df.head()
# Out:
#    Entry number  daily_screen_time  app_sessions  social_media_usage  \
# 0             0                  2            29                   0
# 1             1                  6            29                   1
# 2             2                  9            28                   2
# 3             3                  6            39                   2
# 4             4                  5            37                   3
#
#    gaming_time  notifications  night_usage  age  work_study_hours  \
# 0            0             49            0   44                 5
# 1            2             65            1   29                 5
# 2            0             57            3   28                 7
# 3            0             69            1   28                 6
# 4            1             64            2   27                 4
#
#    stress_level  apps_installed      addicted
# 0             3              35  not addicted
# 1             9              21      addicted
# ...

# %%
df = df.drop(columns=['Entry number'])
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
target_corr = correlation_matrix['daily_screen_time'].sort_values(ascending=False)
print("Correlation with daily_screen_time:\n", target_corr)
# Out:
# Correlation with daily_screen_time:
#  daily_screen_time     1.000000
# notifications         0.305850
# app_sessions          0.260311
# stress_level          0.209982
# apps_installed        0.161269
# social_media_usage    0.160076
# night_usage           0.132892
# gaming_time           0.125346
# work_study_hours     -0.094685
# age                  -0.137602
# Name: daily_screen_time, dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
weak_features = target_corr[abs(target_corr) < 0.1].index.tolist()
print("Weakly correlated features to drop:", weak_features)
# Out:
# Weakly correlated features to drop: ['work_study_hours']
